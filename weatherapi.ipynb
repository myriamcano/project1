# %%
# key has been hidden for privacy reasons

import urllib.request
import sys

import csv
import codecs
        
try: 
  ResultBytes = urllib.request.urlopen("https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/bangkok/2018-01-01/2019-12-31?unitGroup=metric&include=hours&key={key}&contentType=csv")
  
  # Parse the results as CSV
  CSVText = csv.reader(codecs.iterdecode(ResultBytes, 'utf-8'))
        
except urllib.error.HTTPError  as e:
  ErrorInfo= e.read().decode() 
  print('Error code: ', e.code, ErrorInfo)
  sys.exit()
except  urllib.error.URLError as e:
  ErrorInfo= e.read().decode() 
  print('Error code: ', e.code,ErrorInfo)
  sys.exit()

# %%
data=pd.DataFrame(CSVText)

# %%
data
# Out:
#                              0                    1     2          3     4   \
# 0                          name             datetime  temp  feelslike   dew
# 1      กรุงเทพมหานคร, ประเทศไทย  2018-01-01T00:00:00  25.2       25.2  19.2
# 2      กรุงเทพมหานคร, ประเทศไทย  2018-01-01T01:00:00  25.4       25.4  20.1
# 3      กรุงเทพมหานคร, ประเทศไทย  2018-01-01T02:00:00  24.2       24.2  18.5
# 4      กรุงเทพมหานคร, ประเทศไทย  2018-01-01T03:00:00    24         24  18.5
# ...                         ...                  ...   ...        ...   ...
# 17516  กรุงเทพมหานคร, ประเทศไทย  2019-12-31T19:00:00  30.8       35.1  22.9
# 17517  กรุงเทพมหานคร, ประเทศไทย  2019-12-31T20:00:00  29.7       32.1  20.7
# 17518  กรุงเทพมหานคร, ประเทศไทย  2019-12-31T21:00:00  29.5       31.9    21
# 17519  กรุงเทพมหานคร, ประเทศไทย  2019-12-31T22:00:00  27.8         31  22.9
# 17520  กรุงเทพมหานคร, ประเทศไทย  2019-12-31T23:00:00  28.5       30.7    21
#
# ...

# %%
data.to_csv('meteorological_data_bangkok_2018_2019.csv', index=True)
